# %%
# !pip install -q -U google-genai langchain

# %%
from google import genai
from google.colab import userdata

# %%
key = userdata.get("GeminiAPIKey")

print("API key loaded successfully")
# Out:
# API key loaded successfully

# %%
client = genai.Client(api_key=key)

# %%
prompt_text = "What is Cloud Computing?"

# %%
response = client.interactions.create(
    model="gemini-3.6-flash",
    input=prompt_text
)

# %%
print(response.output_text)
# Out:
# At its simplest, **cloud computing** is the delivery of computing services—including servers, storage, databases, networking, software, and analytics—over the internet (“the cloud”).
#
# Instead of buying, owning, and maintaining physical data centers or servers, you rent access to technology services on an as-needed basis from a cloud provider like Amazon Web Services (AWS), Microsoft Azure, or Google Cloud.
#
# ---
#
# ### An Everyday Analogy
# Think of cloud computing like **electricity in your home**:
# * You don't build your own power plant to light your house.
# * Instead, you plug into the power grid, use as much electricity as you need, and pay only for what you consume.
# * Cloud computing works the same way, but with computing power and data storage instead of electricity.
#
# ---
#
# ### Examples You Probably Use Every Day
# If you use an online service to send email, edit documents, watch movies, listen to music, or store pictures, cloud computing is likely making it possible behind the scenes:
# * **Streaming Services:** Netflix, Spotify, Disney+
# * **Cloud Storage:** Google Drive, Apple iCloud, Dropbox
# * **Productivity Tools:** Microsoft 365, Google Docs, Zoom
# * **Email:** Gmail, Yahoo Mail, Outlook
#
# ---
#
# ### The 3 Main Types of Cloud Services
# Cloud computing is usually broken down into three different categories (often referred to as the "Cloud Stack"):
#
# 1. **SaaS (Software as a Service):**
#    * A complete, ready-to-use application delivered over the internet. You just log in and use it.
#    * *Examples:* Gmail, Microsoft 365, Salesforce, Netflix.
#
# 2. **PaaS (Platform as a Service):**
#    * Provides a framework for developers to build, test, and deploy software without worrying about managing the underlying servers or operating systems.
#    * *Examples:* Heroku, Google App Engine, AWS Elastic Beanstalk.
#
# 3. **IaaS (Infrastructure as a Service):**
#    * Provides basic, raw computing building blocks—like virtual computers, hard drive space, and network firewalls. You have maximum control over the hardware.
#    * *Examples:* AWS (EC2), Google Compute Engine, Microsoft Azure VMs.
#
# ---
#
# ### Where Does the Cloud Live? (Deployment Models)
# * **Public Cloud:** Owned and operated by a third-party provider (e.g., AWS, Microsoft). Multiple customers share the same physical hardware, though data is strictly isolated.
# * **Private Cloud:** Computing infrastructure used exclusively by one business or organization. It can be physically located at the company's on-site data center or hosted by a third party.
# * **Hybrid Cloud:** Combines public and private clouds, allowing data and apps to be shared between them. A company might keep sensitive customer data on a private cloud, but run its high-traffic public website on a public cloud.
#
# ---
#
# ### Why Companies Use Cloud Computing (Key Benefits)
# * **Cost Savings:** You don't need to buy expensive servers or pay for the electricity and cooling to run them. You pay only for what you use.
# * **Speed and Agility:** Huge amounts of computing power can be accessed in seconds with a few mouse clicks.
# * **Global Scale:** You can deploy applications to users all over the world instantly, ensuring low lag.
# * **Reliability:** Cloud providers have data backups and redundant hardware spread across multiple geographical locations, making data loss and system downtime rare.
# * **Security:** Top cloud providers invest billions in cybersecurity, often making them far more secure than a company’s local network.
